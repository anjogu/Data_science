# %% [markdown]
# ## Introduction to Data Science
#
# This is an interdisciplinary field that uses scientific method, processes, algorithims and systems to extract knowledge and insights from data. It is related to data mining, machine learning, and big data.
# ![image.png](attachment:image.png)
